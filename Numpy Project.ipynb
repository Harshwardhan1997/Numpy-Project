# %%
class Operator:
    
    def assignmentoperator(rp):
        
        import numpy as np
        row = int(input("Enter The No. Of Rows :"))
        col = int(input("Enter The No. Of Cols :"))
        print("\nThe given matrix has",row,"rows nd",col,"column")
        print("\nThe Total No. of Elements in matrix M1 and M2 Are :",row*col)
       
        a=list(map(int,input("\nEnter the element of matrix M1: ").split()))
        b=list(map(int,input("\nEnter the element of matrix M2: ").split()))
        
        p = np.array(a)
        p = p.reshape(row,col)
        p = np.array(p,ndmin=int(input("\nEnter The Dimension of Matrix M1 Less Than 32 :")))
        print(p)
        print("\nThe Dimension of The Array Is :",p.ndim)
        q = np.array(b)
        q = q.reshape(row,col)
        q = np.array(q,ndmin=int(input("\nEnter The Dimension of Matrix M1 Less Than 32 :")))
        print(q)
        print("\nThe Dimension of The Array Is :",q.ndim)
        
        print("\n",p)
        print("\n",q)
        s=input("\nEnter the operations(Addition,Subtraction,Division,Multiplication,Dot Product,Matrix Square root,Matrix Summation,Matrix Summation column wise,Matrix Summation row wise,Matrix Transposition,Floor Division,Modulus): ")
        
        import numpy as np
        if s=="Addition":
            print("\n Addition of two Matrix(M1 nd M2) is :")
            ad= np.add(p,q)
            print(ad,type(ad))
            print("\n The Dimension of Matrix is : ---->",ad.ndim)
            np.add?
        
        elif s=="Subtraction":
            print("\n Subtraction of two Matrix(M1 nd M2) is :")
            sb= np.subtract(p,q)
            print(sb,type(sb))
            print("\nThe Dimension of Matrix is : ---->",sb.ndim)
            np.subtract?
            
        elif s=="Division":
            print("\n Division of two Matrix(M1 nd M2) is :")
            div= np.divide(p,q)
            print(div,type(div))
            print("\nThe Dimension of Matrix is : ---->",div.ndim)
            np.divide?
            
        elif s=="Multiplication":
            print("\n Multiplication of two Matrix(M1 nd M2) is :")
            mul= np.multiply(p,q)
            print(mul,type(mul))
            print("\nThe Dimension of Matrix is : ---->",mul.ndim)
            np.multiply?
            
        elif s=="Dot Product":
            print("\n The product of two Matrix(M1 nd M2) is :")
            dot= np.dot(p,q)
            print(dot,type(dot))
            print("\nThe Dimension of Matrix is : ---->",dot.ndim)
            np.dot?
            
        elif s=="Matrix Square root":
            print("\n Square root of Matrix M1 is :")
            sqrt= np.sqrt(p)
            print(sqrt,type(sqrt))
            print("\n Square root of Matrix M2 is :")
            sqrt1= np.sqrt(p)
            print(sqrt1,type(sqrt1))
            print("\nThe Dimension of Matrix is : ---->",sqrt.ndim)
            np.sqrt?
            
        elif s=="Matrix Summation":
            print("\n The Summation of elements of Matrix M1 is :")
            sum= np.sum(p)
            print(sum,type(sum))
            print("\n Summation of elements of Matrix M2 is :")
            sum1= np.sum(q)
            print(sum1,type(sum1))
            np.sum?
            
            
        elif s=="Matrix Summation column wise":
            print("\n The Column wise Summation of elements of Matrix M1 is :")
            sum= np.sum(p,axis=0)
            print(sum,type(sum))
            print("\n The Column wise Summation of elements of Matrix M2 is :")
            sum1= np.sum(q,axis=0)
            print(sum1,type(sum1))
            
        elif s=="Matrix Summation row wise":
            print("\n The Row wise Summation of elements of Matrix M1 is :")
            sum= np.sum(p,axis=1)
            print(sum,type(sum))
            print("\n The Row wise Summation of elements of Matrix M2 is :")
            sum1= np.sum(q,axis=1)
            print(sum1,type(sum1))
            
        elif s=="Matrix Transposition":
            print("\n The Transposition of Matrix M1 is :")
            trans= p.T
            print(trans,type(trans))
            print("\n The Transposition root of Matrix M2 is :")
            trans1= q.T
            print(trans1,type(trans1))
            
        elif s=="Floor Division":
            print("\n Floor Division of two Matrix(M1 nd M2) is :")
            div=p//q
            print(div,type(div))
            print("\nThe Dimension of Matrix is : ---->",div.ndim)
            
        elif s=="Modulus":
            print("\n Floor Division of two Matrix(M1 nd M2) is :")
            div=p%q
            print(div,type(div))
            print("\nThe Dimension of Matrix is : ---->",div.ndim)
            
    def binaryoperator(rp):
        
        import numpy as np
        row = int(input("Enter The No. Of Rows :"))
        col = int(input("Enter The No. Of Cols :"))
        print("\nThe given matrix has",row,"rows nd",col,"column")
        print("\nThe Total No. of Elements in matrix M1 and M2 Are :",row*col)
       
        a=list(map(int,input("\nEnter the element of matrix M1: ").split()))
        b=list(map(int,input("\nEnter the element of matrix M2: ").split()))
        
        p = np.array(a)
        p = p.reshape(row,col)
        p = np.array(p,ndmin=int(input("\nEnter The Dimension of Matrix M1 Less Than 32 :")))
        print(p)
        print("\nThe Dimension of The Array Is :",p.ndim)
        q = np.array(b)
        q = q.reshape(row,col)
        q = np.array(q,ndmin=int(input("\nEnter The Dimension of Matrix M1 Less Than 32 :")))
        print(q)
        print("\nThe Dimension of The Array Is :",q.ndim)
        
        print("\n",p)
        print("\n",q)
        

            
        
        s=input("\nEnter the Binary Operator (Bitwise_and, Bitwise_or, Bitwise_xor, Bitwise_not, Bitwise_invert, Binary_repr, Binary_left_shift, Binary_right_shift): ")
        
        import numpy as np
        
        if s=="Bitwise_and":
            print("The Bitwise_and of Matrix M1 and M2 Is :\n")
            print(np.bitwise_and(p,q))
            np.bitwise_and?
        
        elif s=="Bitwise_or":
            print("The Bitwise_or of Matrix M1 and M2 Is :\n")
            print(np.bitwise_or(p,q))
            np.bitwise_or?
            
        elif s=="Bitwise_xor":
            print("The Bitwise_xor of Matrix M1 and M2 Is :\n")
            print(np.bitwise_xor(p,q))
            np.bitwise_xor?
            
        elif s=="Bitwise_not":
            print("The Bitwise_not of Matrix M1 is :\n")
            print(np.bitwise_not(p))
            print("The Bitwise_not of Matrix M2 is :\n")
            print(np.bitwise_not(q))
            np.bitwise_not?
            
        elif s=="Bitwise_invert":
            print("The Bitwise_invert of Matrix M1 is :\n")
            print(np.invert(p))
            print("The Bitwise_invert of Matrix M2 is :\n")
            print(np.invert(q))
            np.invert?
        
        
        elif s=="Binary_repr":
            a=int(input("Enter the binary_repr no :"))
            b=int(input("Enter the width : "))
            print("The Bitwise_repr of No ",a," is :\n")
            print(np.binary_repr(a,width=b))
            np.binary_repr?
            
        elif s=="Binary_left_shift":
            value = int(input("Enter The Value of a : "))
            bit = int(input("Enter The Bit No : "))
            print("The Left_shift Is :")
            print(np.left_shift(value,bit))
            np.left_shift?
            
            
        elif s=="Binary_right_shift":
            value = int(input("Enter The Value of a : "))
            bit = int(input("Enter The Bit No : "))
            print("The right_shift Is :")
            print(np.right_shift(value,bit))
            np.right_shift?
        
    def staticaloperator(rp):
        
        import numpy as np
        from statistics import mean,fmean,geometric_mean,harmonic_mean,median,median_low,median_high,median_grouped,mode,multimode,pstdev,pvariance,stdev,variance
        from math import isnan
        from itertools import filterfalse

        a=list(map(float,input("Enter the element of matrix M1: ").split()))
        p = np.array(a)
        
        a = sorted(p)
        print(a)
        s=input("Enter the function:(mean,fmean,geometric_mean,harmonic_mean,median,median_low,median_high,median_grouped,mode,multimode,pstdev,pvariance,stdev,variance,covariance,correlation) : ")
        if s=="mean":
            print("mean:")
            print(mean(a))
            mean?
            
        elif s=="fmean":
            print("fmean:")
            print(fmean(a))
            fmean?
            
        elif s=="geometric_mean":
            print("geometric_mean:")
            print(round(geometric_mean(a),1))
            geometric_mean?
            
        elif s=="harmonic_mean":
            print("harmonic_mean:")
            print(harmonic_mean(a))
            harmonic_mean?
            
        elif s=="median":
            print("median:")
            print(median(a))
            median?
            
        elif s=="median_low":
            print("median_low:")
            print(median_low(a))
            median_low?
            
        elif s=="median_high":
            print("median_high:")
            print(median_high(a))
            median_high?
            
        elif s=="median_grouped":
            print("median_grouped:")
            print(median_grouped(a))
            median_grouped?
            
        elif s=="mode":
            print("mode:")
            print(mode(a))
            mode?
            
        elif s=="multimode":
            print("multimode:")
            print(multimode(a))
            multimode?
            
        elif s=="pstdev":
            print("pstdev:")
            print(pstdev(a))
            pstdev?
            
        elif s=="pvariance":
            print("pvariance:")
            print(pvariance(a))
            pvariance?
            
        elif s=="stdev":
            print("stdev:")
            print(stdev(a))
            stdev?
            
        elif s=="variance":
            print("variance:")
            print(variance(a))
            variance?
            
        elif s=="covariance":
            x=list(map(float,input("Enter the element of X: ").split()))
            y=list(map(float,input("Enter the element of Y: ").split()))
            print("covariance(x,y):")
            print(np.cov(x,y))
            np.cov?
            
        elif s=="correlation":
            x=list(map(float,input("Enter the element of X: ").split()))
            y=list(map(float,input("Enter the element of Y: ").split()))
            print("corelation(x,y):")
            print(np.corrcoef(x,y))
            np.corrcoef?

# %%
obj=Operator()
s=input("Enter the type of operator(assignmentoperator,binaryoperator,staticaloperator ): ")
if s=="assignmentoperator":
    obj.assignmentoperator()
elif s=="binaryoperator":
    obj.binaryoperator()
elif s=="staticaloperator":
    obj.staticaloperator()
